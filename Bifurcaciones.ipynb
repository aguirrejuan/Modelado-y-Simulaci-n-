# %% [markdown]
# # <center>Bifurcaciones

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
fs = 1000
t = np.arange(-2,2,1/fs)
x = np.arange(-2,2,1/fs)
def dx(t,x):
    r = 1
    return r*x - x** 3

# %%
d_x = dx(t,x)

# %%
plt.plot(x,d_x)
plt.grid()
plt.xlabel('x')
plt.ylabel('dx/dt')
# Out:
# Text(0, 0.5, 'dx/dt')

# %%
x[(d_x > - 1/(fs*2)) & (d_x<1/(2*fs))]
# Out:
# array([-1.00000000e+00, -2.20268248e-13,  1.00000000e+00])

# %%
plt.plot(y,h)
plt.grid()

# %%
y[h == 0]
# Out:
# array([-5])

# %%
h[5]
# Out:
# 5
